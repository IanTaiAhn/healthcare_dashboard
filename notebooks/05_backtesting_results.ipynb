# %% [markdown]
# # 05 — Backtesting Results
#
# **Goal:** Full walk-forward validation of the selected model.
# Generate publication-quality plots showing forecast vs. actuals,
# confidence interval coverage, and error distributions.
#
# **This notebook produces the artifacts that go into the methodology
# section of the dashboard and the README.**
#
# **Metrics:**
# - MAE at 1, 3, 6 month horizons
# - MAPE at 1, 3, 6 month horizons
# - 80% and 95% CI coverage rates
# - Error distribution histograms
# - Forecast vs. actual overlay plots

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / 'backend'))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 5)
plt.rcParams['font.family'] = 'sans-serif'

# %%
# TODO: Load selected model and run full walk-forward evaluation
#
# from models.evaluate import walk_forward_evaluation
#
# results = walk_forward_evaluation(
#     series=target,
#     model_fit_fn=fit_selected_model,
#     model_forecast_fn=forecast_selected_model,
#     train_end='2021-12-31',
#     test_start='2022-01-01',
#     test_end='2024-12-31',
#     horizons=[1, 3, 6],
# )

print('Walk-forward evaluation: implement after model selection in notebook 04')

# %%
# Placeholder: forecast vs actual overlay plot
#
# fig, ax = plt.subplots(figsize=(14, 6))
# ax.plot(actuals.index, actuals.values, 'k-', label='Actual', linewidth=1.5)
# ax.plot(forecast_dates, forecast_values, 'b--', label='Forecast (6m)', linewidth=1.5)
# ax.fill_between(forecast_dates, lower_80, upper_80, alpha=0.15, color='blue', label='80% CI')
# ax.axvline(pd.Timestamp('2022-01-01'), color='gray', linestyle=':', label='Test start')
# ax.set_xlabel('Date')
# ax.set_ylabel('Employment (thousands)')
# ax.set_title('Utah Healthcare Employment: Forecast vs. Actual (2022–2024)')
# ax.legend(loc='upper left')
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
# plt.tight_layout()
# plt.savefig('backtest_forecast_vs_actual.png', dpi=150)
# plt.show()

print('Plots: generate after walk-forward evaluation is complete')

# %%
# Coverage analysis
#
# print(f'80% CI coverage: {coverage_80:.1%} (target: 80%)')
# print(f'95% CI coverage: {coverage_95:.1%} (target: 95%)')
#
# if coverage_80 < 0.70:
#     print('⚠ 80% CI is underconfident — bands may be too narrow')
# elif coverage_80 > 0.90:
#     print('⚠ 80% CI is overconfident — bands may be too wide')
# else:
#     print('✓ 80% CI coverage is well-calibrated')

print('Coverage analysis: implement after evaluation')

# %% [markdown]
# ## Final Results Summary
#
# | Metric | 1-Month | 3-Month | 6-Month |
# |--------|---------|---------|--------|
# | MAE (selected) | TBD | TBD | TBD |
# | MAE (naive) | TBD | TBD | TBD |
# | MAPE (selected) | TBD | TBD | TBD |
# | 80% Coverage | TBD | TBD | TBD |
#
# **Conclusion:** TBD
#
# **Artifacts produced:**
# - `backtest_forecast_vs_actual.png`
# - `backtest_error_distribution.png`
# - `backtest_coverage_plot.png`
# - Updated `model_metadata.json`
